# %%
import numpy as np
import cv2
from IPython.display import clear_output
import time
from PIL import Image

# %%
cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi', fourcc, 20.0, (640, 480))

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 0)
        out.write(frame)

        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        display(Image.fromarray(frame_rgb))
        clear_output(wait=True)

        time.sleep(0.03)


except KeyboardInterrupt:
    print("Gravação interrompida manualmente.")

finally:
    print("Salvando vídeo...")
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print("Vídeo salvo como output.avi")
# Out:
# Gravação interrompida manualmente.
# Salvando vídeo...
# Vídeo salvo como output.avi

# %%
cap = cv2.VideoCapture("output.avi")

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("output_convertido3.mp4", fourcc, 20.0, (640, 480))

while True:
    ret, frame = cap.read()
    if not ret:
        break
    out.write(frame)

cap.release()
out.release()
